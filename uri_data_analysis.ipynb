# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="dark", palette="colorblind", context="paper")

uri = pd.read_csv('uri_challenges_complete.csv', index_col='Number')
uri.head()
# Out:
#             Class                Title  Level  Points  \
# Number
# 1000    INICIANTE         Hello World!      5     5.0
# 1001    INICIANTE  Extremamente Básico      4     4.2
# 1002    INICIANTE      Área do Círculo      4     4.9
# 1003    INICIANTE         Soma Simples      1     1.2
# 1004    INICIANTE      Produto Simples      1     1.3
#
#                                                       URL
# Number
# 1000    https://www.urionlinejudge.com.br/judge/pt/pro...
# 1001    https://www.urionlinejudge.com.br/judge/pt/pro...
# 1002    https://www.urionlinejudge.com.br/judge/pt/pro...
# 1003    https://www.urionlinejudge.com.br/judge/pt/pro...
# 1004    https://www.urionlinejudge.com.br/judge/pt/pro...

# %%
class_map = {'INICIANTE': 'Beginner',
             'ESTRUTURAS E BIBLIOTECAS': 'Data Structures\nand Libraries', 
             'STRINGS': 'Strings', 
             'AD-HOC': 'Ad-Hoc',
             'PARADIGMAS': 'Programming\nParadigms', 
             'MATEMÁTICA': 'Mathematics', 
             'GEOMETRIA COMPUTACIONAL': 'Computational\nGeometry', 
             'GRAFOS': 'Graphs',
             'SQL': 'SQL'}

uri['Class'] = uri['Class'].map(class_map)

# %%
freq_per_type = uri['Class'].value_counts()
perc_per_type = uri['Class'].value_counts(normalize=True)*100

uri.describe()
# Out:
#              Level       Points
# count  2174.000000  2174.000000
# mean      5.333947     5.736661
# std       2.688760     2.644639
# min       1.000000     1.000000
# 25%       3.000000     3.900000
# 50%       5.000000     5.000000
# 75%       7.000000     7.900000
# max      10.000000    10.900000

# %%
fig, ax1 = plt.subplots(figsize=(15,5), dpi=100)

sns.barplot(x=freq_per_type.index, y=freq_per_type.values, ax=ax1)

for i in range(len(freq_per_type)):
    string = str(perc_per_type.values[i].round(1)) + ' %'
    ax1.text(x=i, y=freq_per_type.values[i]+5, s=string, fontsize=12, fontweight='bold', ha='center')

ax1.tick_params(axis='y', labelsize=12)
ax1.tick_params(axis='x', labelsize=12)

ax1.set_ylabel('Number of Challenges', fontsize=14, fontweight='bold')
ax1.set_xlabel('Categories', fontsize=14, fontweight='bold')

fig.show()
# Out:
# <ipython-input-44-2cebb057ed19>:15: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax1 = plt.subplots(figsize=(15,5), dpi=100)

order = uri.groupby('Class').median()['Points'].sort_values().index
sns.boxplot(x='Class', y='Points', data=uri, ax=ax1, width=0.8, order=order)

ax1.tick_params(axis='y', labelsize=12)
ax1.tick_params(axis='x', labelsize=12)

ax1.set_ylabel('Points per Challenge', fontsize=14, fontweight='bold')
ax1.set_xlabel('Categories', fontsize=14, fontweight='bold')

fig.show()
# Out:
# <ipython-input-64-18671aec25d0>:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
top_10_easiest = uri.sort_values(by='Points').head(10)
top_10_easiest
# Out:
#            Class                             Title  Level  Points  \
# Number
# 1143    Beginner                Quadrado e ao Cubo      1     1.0
# 2416      Ad-Hoc                           Corrida      1     1.0
# 3048      Ad-Hoc                 Sequência Secreta      1     1.0
# 2061    Beginner               As Abas de Péricles      1     1.0
# 2006    Beginner               Identificando o Chá      1     1.0
# 2058      Ad-Hoc  Triângulos e Polígonos Regulares      1     1.0
# 1153    Beginner                  Fatorial Simples      1     1.0
# 1016    Beginner                         Distância      1     1.0
# 2615         SQL              Expandindo o Negocio      1     1.0
# 2936    Beginner                  Quanta Mandioca?      1     1.0
#
#                                                       URL
# Number
# 1143    https://www.urionlinejudge.com.br/judge/pt/pro...
# 2416    https://www.urionlinejudge.com.br/judge/pt/pro...
# ...

# %%
top_10_hardest= uri.sort_values(by='Points', ascending=False).head(10)
top_10_hardest
# Out:
#                                  Class                 Title  Level  Points  \
# Number
# 2559    Data Structures\nand Libraries        Sexta-Feira 13     10    10.9
# 1742                            Graphs  Entrando em Confusão     10    10.9
# 1355                           Strings            Compressor     10    10.9
# 1531                       Mathematics    Fibonacci de Novo!     10    10.8
# 1369                            Ad-Hoc     Gerente de Espaço     10    10.8
# 1511    Data Structures\nand Libraries         Tabuleiro GCD     10    10.8
# 1740    Data Structures\nand Libraries        Está Ordenado?     10    10.8
# 1692                            Graphs           Curo Ataque     10    10.8
# 1090                            Ad-Hoc                   Set     10    10.8
# 2226            Programming\nParadigms     Fabrica de Balões     10    10.8
#
#                                                       URL
# Number
# ...
